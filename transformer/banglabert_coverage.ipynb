# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 19.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 34.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 47.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 48.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 30.6 MB/s eta 0:00:00
# ...

# %%
# !pip install git+https://github.com/csebuetnlp/normalizer
# Out:
# ...
#   Cloning https://github.com/csebuetnlp/normalizer to /tmp/pip-req-build-guftm6s4
#   Running command git clone --filter=blob:none --quiet https://github.com/csebuetnlp/normalizer /tmp/pip-req-build-guftm6s4
#   Resolved https://github.com/csebuetnlp/normalizer to commit d405944dde5ceeacb7c2fd3245ae2a9dea5f35c9
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.0/185.0 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 6.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for normalizer: filename=normalizer-0.0.1-py3-none-any.whl size=6857 sha256=3b02a2a9abb4f2005b5bdf0d92a290b8995c97c0639285d5d68f87f797156b20
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dga4p2cf/wheels/2e/79/9c/cd96d490298305d51d2da11484bb2c25fd1f759a6906708282
# ...

# %%
from transformers import AutoModelForPreTraining, AutoTokenizer
from normalizer import normalize
import torch

# Load the tokenizer associated with BanglaBERT
model = AutoModelForPreTraining.from_pretrained("csebuetnlp/banglabert")
tokenizer = AutoTokenizer.from_pretrained("csebuetnlp/banglabert")


# Load your dataset
dataset_path = "/content/drive/MyDrive/Research/VITD/Research/Shared Task/Violence Inciting Text Detection (VITD) Bangla/dataset/task datasets/original/train.csv"
dataset = pd.read_csv(dataset_path, encoding='utf-8', error_bad_lines=False)
# Out:
# ...
# <ipython-input-6-1d2cc4a491da>:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   dataset = pd.read_csv(dataset_path, encoding='utf-8', error_bad_lines=False)

# %%
# Tokenize the text data
tokenized_data = tokenizer.batch_encode_plus(text_data.tolist(), add_special_tokens=True, return_token_type_ids=False, return_attention_mask=False, truncation=True)

# Get the unique tokens from the tokenized data
unique_tokens = set(token for encoding in tokenized_data['input_ids'] for token in encoding)

# Get the vocabulary of the BanglaBERT model
model_vocab = set(tokenizer.get_vocab().keys())

# %%
def tokenize(text):
    return text.split()  # Basic whitespace-based tokenization; replace with your preferred tokenizer
    # Read your task dataset file
with open("/content/drive/MyDrive/Research/VITD/Research/Shared Task/Violence Inciting Text Detection (VITD) Bangla/dataset/task datasets/original/train.csv", "r", encoding="utf-8", errors="ignore") as file:
    train_dataset_text = file.read()

# Tokenize the datasets
# my_dataset_tokens = set(tokenize(my_dataset_text))
train_dataset_tokens = set(tokenize(train_dataset_text))

# %%
# Calculate coverage
coverage = len(train_dataset_tokens.intersection(model_vocab)) / len(train_dataset_tokens)

# %%
print(f"Coverage of the Train dataset by your dataset: {coverage * 100:.2f}%")
# Out:
# Coverage of the Train dataset by your dataset: 35.00%

# %%
# Read your task dataset file
with open("/content/drive/MyDrive/Research/VITD/Research/Shared Task/Violence Inciting Text Detection (VITD) Bangla/dataset/task datasets/original/validation.csv", "r", encoding="utf-8", errors="ignore") as file:
    dev_dataset_text = file.read()

# Tokenize the datasets
# my_dataset_tokens = set(tokenize(my_dataset_text))
dev_dataset_tokens = set(tokenize(dev_dataset_text))

# Calculate coverage
coverage = len(dev_dataset_tokens.intersection(model_vocab)) / len(dev_dataset_tokens)
# Calculate coverage
print(f"Coverage of the Dev dataset by your dataset: {coverage * 100:.2f}%")
# Out:
# Coverage of the Dev dataset by your dataset: 40.49%

# %%
# Read your task dataset file
with open("/content/drive/MyDrive/Research/VITD/Research/Shared Task/Violence Inciting Text Detection (VITD) Bangla/dataset/task datasets/original/test.csv", "r", encoding="utf-8", errors="ignore") as file:
    test_dataset_text = file.read()

# Tokenize the datasets
# my_dataset_tokens = set(tokenize(my_dataset_text))
test_dataset_tokens = set(tokenize(test_dataset_text))

# Calculate coverage
coverage = len(test_dataset_tokens.intersection(model_vocab)) / len(test_dataset_tokens)
print(f"Coverage of the test dataset by your dataset: {coverage * 100:.2f}%")
# Out:
# Coverage of the test dataset by your dataset: 35.82%

# %%
task_dataset_text = dev_dataset_text+train_dataset_text+test_dataset_text

# Tokenize the datasets
# my_dataset_tokens = set(tokenize(my_dataset_text))
task_dataset_tokens = set(tokenize(task_dataset_text))

# Calculate coverage
coverage = len(set(task_dataset_tokens).intersection(set(model_vocab))) / len(set(task_dataset_tokens))

print(f"Coverage of the dev by your dataset: {coverage * 100:.2f}%")
# Out:
# Coverage of the dev by your dataset: 27.33%
