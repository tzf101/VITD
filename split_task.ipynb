# %% [markdown]
# # Setup project structure

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/Research/Shared Task/Violence Inciting Text Detection (VITD) Bangla"
# Out:
# /content/drive/MyDrive/Research/Shared Task/Violence Inciting Text Detection (VITD) Bangla

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Research/Shared Task/Violence Inciting Text Detection (VITD) Bangla'

# %%
# %ls
# Out:
# dataset/  embedding/  models/  notebooks/

# %% [markdown]
# # Bnlp stopword and punctuation removal

# %%
# !pip install bnlp-toolkit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 7.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.5/993.5 kB 11.4 MB/s eta 0:00:00
# ...
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171033 sha256=78741a319d205a1eb00242cfc5ed9c730c73759a04a487baf462f630908742f1
#   Stored in directory: /root/.cache/pip/wheels/31/8a/8c/315c9e5d7773f74b33d5ed33f075b49c6eaeb7cedbb86e2cf8
# Successfully built emoji
# ...

# %% [markdown]
# # Creating a train test val split for labelled data

# %% [markdown]
# ### Loading

# %%
import pandas as pd

# %%
dataset_path = "dataset/task datasets/original/"
train_df = pd.read_csv(dataset_path+"train.csv")
test_df = pd.read_csv(dataset_path+"test.csv")
val_df = pd.read_csv(dataset_path+"dev.csv")

# %%
# remove punctuation
# Initialize CleanText object
clean_text = CleanText(
   fix_unicode=True,
   unicode_norm=True,
   unicode_norm_form="NFKC",
   remove_url=True,
   remove_email=True,
   remove_emoji=False,
   remove_number=True,
   remove_digits=True,
   remove_punct=True,
   replace_with_url="<URL>",
   replace_with_email="<EMAIL>",
   replace_with_number="<NUMBER>",
   replace_with_digit="<DIGIT>",
   replace_with_punct="<PUNC>"
)

train_df['text'] = train_df['text'].apply(clean_text)

# Apply the clean_text object to the "text" column of val_df
val_df['text'] = val_df['text'].apply(clean_text)
test_df['text'] = test_df['text'].apply(clean_text)
# Out:
# Streaming output truncated to the last 5000 lines.
# ।
# ঃ
# !
# "
# #
# $
# %
# &
# '
# (
# )
# *
# +
# ,
# -
# .
# /
# :
# ;
# <
# =
# >
# ?
# @
# [
# \
# ]
# ^
# _
# `
# {
# |
# }
# ~
# ।
# ঃ
# !
# "
# #
# $
# %
# &
# '
# (
# )
# *
# +
# ,
# -
# .
# /
# :
# ;
# <
# =
# >
# ?
# @
# [
# \
# ]
# ^
# _
# `
# {
# |
# }
# ~
# ।
# ঃ
# !
# "
# #
# $
# %
# &
# '
# (
# )
# *
# +
# ,
# -
# .
# /
# :
# ;
# <
# =
# >
# ?
# @
# [
# \
# ]
# ^
# _
# `
# {
# |
# }
# ~
# ।
# ঃ
# !
# "
# #
# $
# %
# &
# '
# (
# )
# *
# +
# ,
# -
# .
# /
# :
# ;
# <
# =
# >
# ?
# @
# [
# \
# ]
# ^
# _
# `
# {
# |
# }
# ~
# ।
# ঃ
# !
# "
# #
# $
# %
# &
# '
# (
# )
# *
# +
# ,
# -
# .
# /
# :
# ;
# <
# =
# >
# ?
# @
# [
# \
# ]
# ^
# _
# `
# {
# |
# }
# ~
# ।
# ঃ
# !
# "
# #
# $
# %
# &
# '
# (
# )
# *
# +
# ,
# -
# .
# /
# :
# ;
# <
# =
# >
# ?
# @
# [
# \
# ]
# ^
# _
# `
# {
# |
# }
# ~
# ।
# ঃ
# !
# "
# #
# $
# %
# &
# '
# (
# )
# *
# +
# ,
# -
# .
# /
# :
# ;
# <
# =
# >
# ?
# @
# [
# \
# ]
# ^
# _
# `
# {
# |
# ...

# %%
train_df
# Out:
#                                                    text  label
# 0     যে দেশে সন্ত্রাসরা দেশ চালায়সে দেশে শান্তি কি...      1
# 1     এই বিচার শেষ বিচার নয়<PUNC>আসল বিচার হবে আল্ল...      0
# 2     আরব দেশগুলোকে বলব ভারতের সাথে সব ব্যবসা বাণিজ্...      2
# 3                                       দেশটা সুস্থ নাই      0
# 4     আপনার কথা দু<PUNC>খ জনক আগে বিডিও থাকলে কেন ধর...      0
# ...                                                 ...    ...
# 2695  হল বন্ধ করার আগে নিউমার্কেট বন্ধ করা উচিৎ<PUNC...      2
# 2696  এ স্বাধীন দেশে ভোটটা অন্তত<PUNC> আমাদের দিতে দ...      0
# 2697  আল হামদুলিল্লাহ্<PUNC<PUNC>PUNC<PUNC><PUNC<PUN...      0
# 2698      এই গুলা ত বিচার করবায় ঐ তোমরা ত ইন্ডিয়ান না      0
# 2699  ফি আমানিল্লাহ<PUNC> বাংলার জমিনে হযরত মুহাম্মদ...      2
#
# [2700 rows x 2 columns]

# %%
val_df
# Out:
#                                                    text  label
# 0     পাডা পুতার মাঝখানে পরে সাধারণ <DIGIT> মানুষের ...      0
# 1     করোনার চাপে অনেক কিছু বন্ধ ও অনেক বিধি নিষেধ ক...      0
# 2     সঠিক তদন্ত করতে হবে<PUNC> বিচারের আওতায় আনতে ...      0
# 3     যে লোকটা মারা গেছে তার কি হবে তার দায়ভার কে ন...      0
# 4     নিউ মার্কেট এবং গুলিস্থান মার্কেটের ব্যবসায়ীর...      1
# ...                                                 ...    ...
# 1325  নাটক টা সুন্দর ভাবে সাজিয়েছে আরো কত কিছু দেখত...      1
# 1326  নোংরা দেশ আর নোংরা জাতি হচ্ছে ভারত এঁরা কি বুঝ...      1
# 1327                        জে ছেলে মারা গেছে ওর কি হবে      0
# 1328                           এরাই নৈরাজ্য সৃষ্টি করছে      1
# 1329  ব্রাহ্মণবাড়িয়ার হত্যা হলে<PUNC<PUNC>PUNC<PUN...      0
#
# [1330 rows x 2 columns]

# %%
# # Apply the remove_stopwords function to the 'text' column
# train_df['text'] = train_df['text'].apply(remove_stopwords)
# val_df['text'] = val_df['text'].apply(remove_stopwords)

# %%
train_df
# Out:
#                                                    text  label
# 0     যে দেশে সন্ত্রাসরা দেশ চালায়সে দেশে শান্তি কি...      1
# 1     এই বিচার শেষ বিচার নয়<PUNC>আসল বিচার হবে আল্ল...      0
# 2     আরব দেশগুলোকে বলব ভারতের সাথে সব ব্যবসা বাণিজ্...      2
# 3                                       দেশটা সুস্থ নাই      0
# 4     আপনার কথা দু<PUNC>খ জনক আগে বিডিও থাকলে কেন ধর...      0
# ...                                                 ...    ...
# 2695  হল বন্ধ করার আগে নিউমার্কেট বন্ধ করা উচিৎ<PUNC...      2
# 2696  এ স্বাধীন দেশে ভোটটা অন্তত<PUNC> আমাদের দিতে দ...      0
# 2697  আল হামদুলিল্লাহ্<PUNC<PUNC>PUNC<PUNC><PUNC<PUN...      0
# 2698      এই গুলা ত বিচার করবায় ঐ তোমরা ত ইন্ডিয়ান না      0
# 2699  ফি আমানিল্লাহ<PUNC> বাংলার জমিনে হযরত মুহাম্মদ...      2
#
# [2700 rows x 2 columns]

# %%
val_df
# Out:
#                                                    text  label
# 0     পাডা পুতার মাঝখানে পরে সাধারণ <DIGIT> মানুষের ...      0
# 1     করোনার চাপে অনেক কিছু বন্ধ ও অনেক বিধি নিষেধ ক...      0
# 2     সঠিক তদন্ত করতে হবে<PUNC> বিচারের আওতায় আনতে ...      0
# 3     যে লোকটা মারা গেছে তার কি হবে তার দায়ভার কে ন...      0
# 4     নিউ মার্কেট এবং গুলিস্থান মার্কেটের ব্যবসায়ীর...      1
# ...                                                 ...    ...
# 1325  নাটক টা সুন্দর ভাবে সাজিয়েছে আরো কত কিছু দেখত...      1
# 1326  নোংরা দেশ আর নোংরা জাতি হচ্ছে ভারত এঁরা কি বুঝ...      1
# 1327                        জে ছেলে মারা গেছে ওর কি হবে      0
# 1328                           এরাই নৈরাজ্য সৃষ্টি করছে      1
# 1329  ব্রাহ্মণবাড়িয়ার হত্যা হলে<PUNC<PUNC>PUNC<PUN...      0
#
# [1330 rows x 2 columns]

# %%
train_df.columns, test_df.columns, val_df.columns
# Out:
# (Index(['text', 'label'], dtype='object'),
#  Index(['text'], dtype='object'),
#  Index(['text', 'label'], dtype='object'))

# %%
train_df.shape, test_df.shape, val_df.shape
# Out:
# ((2700, 2), (2016, 1), (1330, 2))

# %%
# Renaming the "text" columns to "sentence1"

train_df.rename(columns={"text": "sentence1", "label": "label"}, inplace=True)
val_df.rename(columns={"text": "sentence1", "label": "label"}, inplace=True)
test_df.rename(columns={"text": "sentence1"}, inplace=True)
# Adding a new "label" column with constant value 3
test_df["label"] = 0

# %%
import matplotlib.pyplot as plt# Combine all DataFrames into one for analysis
all_data = pd.concat([train_df, test_df, val_df])

# Calculate the length of sentences and create a new column for it
all_data['sentence1_length'] = all_data['sentence1'].apply(len)

# Plot the distribution of sentence lengths
plt.figure(figsize=(10, 6))
plt.hist(all_data['sentence1_length'], bins=50, color='blue', alpha=0.7)
plt.title('Distribution of Sentence Lengths')
plt.xlabel('Sentence Length')
plt.ylabel('Frequency')
plt.show()

# %%
train_df
# Out:
#                                               sentence1  label
# 0     যে দেশে সন্ত্রাসরা দেশ চালায়সে দেশে শান্তি কি...      1
# 1     এই বিচার শেষ বিচার নয়<PUNC>আসল বিচার হবে আল্ল...      0
# 2     আরব দেশগুলোকে বলব ভারতের সাথে সব ব্যবসা বাণিজ্...      2
# 3                                       দেশটা সুস্থ নাই      0
# 4     আপনার কথা দু<PUNC>খ জনক আগে বিডিও থাকলে কেন ধর...      0
# ...                                                 ...    ...
# 2695  হল বন্ধ করার আগে নিউমার্কেট বন্ধ করা উচিৎ<PUNC...      2
# 2696  এ স্বাধীন দেশে ভোটটা অন্তত<PUNC> আমাদের দিতে দ...      0
# 2697  আল হামদুলিল্লাহ্<PUNC<PUNC>PUNC<PUNC><PUNC<PUN...      0
# 2698      এই গুলা ত বিচার করবায় ঐ তোমরা ত ইন্ডিয়ান না      0
# 2699  ফি আমানিল্লাহ<PUNC> বাংলার জমিনে হযরত মুহাম্মদ...      2
#
# [2700 rows x 2 columns]

# %%
test_df
# Out:
#                                               sentence1  label
# 0     বাংলাদেশের হিন্দুরা নিজেদের জন্য আলাদা হিন্দু ...      0
# 1     মাইজদী <PUNC<PUNC>PUNC<PUNC> চৌমুহুনী <PUNC<PU...      0
# 2     দয়া করে পবিত্র কুরআনুল কারিম বলেন<PUNC<PUNC>P...      0
# 3     বিবিসি হলো সত্য কে বিনষ্টকারী আর মিথ্যা কে গ্র...      0
# 4               বুধবার কি তোরা মারা গেছিলি বিবিসি বাংলা      0
# ...                                                 ...    ...
# 2011  নিজের ধর্মের পরিধানটি কোনো ধর্ম স্থানেই ভালো ম...      0
# 2012  হিন্দু মহিলাদের ওপরও বেদের মতে পর্দা করা আবশ্য...      0
# 2013                           ভারত ধ্বংস হবে অতি দ্রুত      0
# 2014  ভারতীয় উপমহাদেশে উপর আল্লাহর গজব নাজিল হোক আম...      0
# 2015  মুসলিম আল্লাহ চাড়া কাউকে ভয় করে না<PUNC><PUN...      0
#
# [2016 rows x 2 columns]

# %%
# Save the DataFrames as CSV files
train_df.to_csv('dataset/Tariq/split/train.csv', index=False)
val_df.to_csv('dataset/Tariq/split/validation.csv', index=False)
test_df.to_csv('dataset/Tariq/split/test.csv', index=False)
